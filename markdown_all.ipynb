# %% [markdown]
# ment with asterisk**"
#    ]
#   },{Add commentMore actions
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "id": "mb23455",
#    "metadata": {},
#    "source": [
#     "# heading 1\n",
#     "## heading 2\n",
#     "### heading 3\n",
#     "#### heading 4\n",
#     "##### heading 5\n",
#     "###### heading 6"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "mb34664",
#    "metadata": {},
#    "source": []
#   },
#   {
#    "cell_type": "markdown",
#    "id": "bgt6c72",
#    "metadata": {},
#    "source": [
#     "**Bold State
#   {
#    "cell_type": "markdown",
#    "id": "456hft6h",
#    "metadata": {},
#    "source": [
#     "__Bold Statement with underscore__"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id":hrfvdwg42",
#    "metadata": {},
#    "source": [
#     "*Italic Statement with asterisk*"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "2edf2ab0",
#    "metadata": {},
#    "source": [
#     "_Italic Statement with underscore_"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "e3fdfb3c",
#    "metadata": {},
#    "source": [
#     "**_Bold with Italic Statement with combination of asterisk and underscore_**"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "c95f8709",
#    "metadata": {},
#    "source": [
#     "***Bold with Italic Statement with asterisk***"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "427c550e",
#    "metadata": {},
#    "source": [
#     "___Bold with Italic Statement with underscore___"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "rgr556yt",
#    "metadata": {},
#    "source": [
#     "1. school\n",
#     "2. vehicles\n",
#     "3. board \n",
#     "    1. carmel\n",
#     "    2. bus\n",
#     "    3. cbse\n",
#     "4. vehical"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "9cbd6432",
#    "metadata": {},
#    "source": [
#     "*place \n",
#     "+ city\n",
#     "* country\n",
#     "    - mahal\n",
#     "    - nagpur \n",
#     "    - india\n",
#     "+ place"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "56tj5566",
#    "metadata": {},
#    "source": [
#     "you can use 'print()' to display output"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "56884hg",
#    "metadata": {},
#    "source": [
#     "### This is python function example\n",
#     "\n",
#     "```python\n",
#     "def addValue(a,b):\n",
#     "    return a+b\n",
#     "```"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "svfkswjn465",
#    "metadata": {},
#    "source": [
#     "> \"TO shine like a sun start burning like it .\"\n",
#     "> - Socrates."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "fvfrdv45",
#    "metadata": {},
#    "source": [
#     "visit the [markdown.ipynb](D:\\DA18\\python\\day1\\markdown.ipynb)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "dfdighib44",
#    "metadata": {},
#    "source": [
#     "---\n",
#     "# Heading 1\n",
#     "___\n",
#     "\n",
#     "---\n",
#     "## Heading 2\n",
#     "***\n",
#     "\n",
#     "---\n",
#     "### Heading 3\n",
#     "___\n"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "d5rgdcc4",
#    "metadata": {},
#    "source": [
#     "| First_name | Middle_name | Last_name\n",
#     "|:--------- |:---------:|---------:|\n",
#     "| priya | Shri | yadav |\n",
#     "| Manoj | ram | sharma |\n",
#     "| mukul | suresh | pande |\n",
#     "| riya  | devrao | tapre |"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "ea693a3b",
#    "metadata": {},
#    "source": [
#     "~~ this is text ~~"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "681ea295",
#    "metadata": {},
#    "source": [
#     "- [X] Complete Markdown Documentation\n",
#     "- [ ] Review Code\n",
#     "- [ ] prepare Presentation"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "58769a32",
#    "metadata": {},
#    "source": [
#     "The famous Euler's identity is $e^{i\\pi} + 1=0$"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "c3696004",
#    "metadata": {},
#    "source": [
#     "$$E=MC^2$$"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "id": "73b5cf18",
#    "metadata": {},
#    "source": []
#   }
#  ],
#  "metadata": {
#   "language_info": {
#    "name": "python"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
